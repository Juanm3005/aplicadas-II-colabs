# %% [markdown]
# <a href="https://colab.research.google.com/github/Juanm3005/aplicadas-II-colabs/blob/main/Entrega_I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Metodos que vamos a usar y su explicación:
#
# **1. Metodo de integración por sustitucion:**
#
# El método de sustitución consiste en elegir una parte de la integral y reemplazarla por una nueva variable u. Luego, se deriva esa elección para expresar el resto de la integral en términos de du. De esta manera, la integral original se transforma en otra más sencilla de resolver.
#
# ejemplo:
# $$\int xcos(x^2)dx$$
#
# Procedemos a identificar los tipos de funciones que son:
#
# *   $x$ siendo algebraica
# *   $cos(x^2)$ siendo trigonometrica
#
# Esto se hace para usar el metodo de ILATE que significa:
#
# I = Inversa trigonométrica
#
# L = Logarítmica
#
# A = Algebraica (polinomios, x,x^2,...)
#
# T = Trigonométrica
#
# E = Exponencial
#
# Según ILATE: A (algebraica) va antes que T (trigonométrica).
# Entonces conviene elegir como
# u la función algebraica relacionada:
# $𝑥^2$
#
# Procedemos a hacer sustitucion $$u=x^2 du=2xdx$$
#
# Para finalizar integramos y resolvemos:
#
# $$∫xcos(x^2)dx= \frac{1}{2}​∫cos(u)du=\frac{1}{2}sin(u)+C=\frac{1}{2}​sin(x^2)+C$$
#
# **2. Fracciones parciales:**
#
# Las fracciones parciales es una técnica de integración que se usa cuando tenemos una función racional (es decir, un cociente de polinomios).
#
# La idea es descomponer una fracción complicada en una suma de fracciones más simples (llamadas fracciones parciales), que son mucho más fáciles de integrar.
#
# Se debe tener una fracion en forma:
#
# $$\frac{P(x)}{Q(x)}$$
#
# donde $P(x)$ y $Q(x)$ son polinomios.
#
# Ejemplo:
#  $$∫\frac{1}{x^2−1}​dx$$
#
# Procedemos a factorizar el denominador, y esa factorizacion se pasa al otro lado de la igualdad, dividenciolas por cualquier constante:
#
# $$\frac{1}{x^2-1} = \frac{A}{x-1} + \frac{B}{x+1}$$
#
# Despues hacemos suma de fracciones y pasamos el denominador a multipilicar al otro lado del igual ppara cancelarlo con $x^2-1$ y nos da como solucion:
#
# $$1=A(x+1)+B(x−1)$$
#
# Con la anterior ecuacion, buscamos hallar los valores de A y de B remplazando $x$ con 1 o -1 para que una de las constantes me de 0 para poder despejar alguna de las 2:
#
# $$x=1$$$$
# 1 = A(1+1) +B(1-1)
# $$$$
# \frac{1}{2}= A
# $$$$
# $$$$x=-1$$$$
# 1= A(-1+1) + B (-1-1)
# $$$$\frac{1}{-2}=B$$
#
# Despues de hallar los valores de A y B los sustituimos en la ecuacion iniciar y resolvemos:
#
# $$\frac{1}{x^2-1} = \frac{\frac{1}{2}}{x-1} + \frac{-\frac{1}{2}}{x+1}$$
#
# $$
# \int \frac{1}{x^2 - 1}\, dx
# = \frac{1}{2}\int \frac{1}{x-1}\, dx
# - \frac{1}{2}\int \frac{1}{x+1}\, dx
# $$
#
# $$
# = \frac{1}{2}\ln|x-1| - \frac{1}{2}\ln|x+1| + C
# $$

# %% [markdown]
# #Modelo Lineal
# 1. Encuentre la solución analítica de la ecuación.
#
# Planteamos la ecuacion inicial:
#
# $$
# \frac{dx}{dt}=r-dx
# $$
#
# donde:
#
# $r$ es el ingreso constante de nuevos estudiantes por año
#
# $d$ es la tasa de deserción proporcional
#
# $x(t)$ es la población universitaria en el tiempo
#
# Para facilidad del lector cambiaremos la variable $d$ por la variable $h$, por lo tanto la ecuacion quedaria como:
#
# $$\frac{dx}{dt}=r-hx$$
#
# Ahora procedemos a despejar la ecuacion para $dt$:
#
# $$dx = (r-hx)dt$$
# $$\frac{dx}{r-hx} = dt$$
#
# Continuamos integrando ambos lados del igual, y en el lado izquierdo aplicando integración por sustitución (Vease el metodo 1 de la seccion metodos que vamos a usar y su explicacion):
#
# $$u=r-hx \quad du=-hdx$$
# $$u =r-hx \quad \frac{du}{-h}=dx$$
#
# Aplicamos integral a ambos lados, remplazamos lo anterior en la ecuacion y integramos $dt$ como $t+c$:
#
# $$\int \frac{1}{u}\frac{du}{-h}= t+c$$
#
# $$\frac{1}{-h}\int\frac{du}{u} = t+c$$
#
# $$\frac{1}{-h} ln(u) = t+c$$
#
# Despues de haber integrado cambiamos la variable u a su valor original:
#
# $$\frac{1}{-h} ln(r-hx) = t+c$$
#
# Ahora pasamos -h a multiplicar y usar la propiedad de distribución:
# $$ln(r-hx)= ht-hc$$
#
# Al tener la constante c multiplicada por algo podemos decir que el resultado seria otra constante entonces la parte $hc$ podemos remplarla con $c_1$.
#
# $$ln(r-hx) = ht-c_1$$
#
# Al euler tener elevado un logaritmo natural estos se pueden cancelar, entonces procedemos a introducir euler en la ecuacion para eliminar el logaritmo natural:
#
# $$e^{ln(r-hx)}= e^{-ht+c_1}$$
#
# $$r-hx = e^{-ht+c_1}$$
#
# Gracias a las propiedades de los exponentes podemos separar $-ht$ y $c_1$ en 2 eulers diferentes y como el resultado de $e^{c_1}$ da una constante podemos decir que es otra constante.
#
# $$r-hx = e^{-ht} A$$
#
# Por ultimo despejamos $x$
#
# $$x= \frac{e^{-ht}A-r}{-h}$$

# %% [markdown]
# # Ejercicio aplicado al modelo lineal
#
# ## Contexto
#
# Una universidad cuenta actualmente con 18.000 estudiantes. Cada año ingresan 2.000 nuevos estudiantes. Se estima que la tasa de deserción anual es del 15 de la población activa. La universidad desea conocer si esta dinámica permitirá mantener o reducir la población en el largo plazo.
#
# ##Modelo aplicado
#
# $$\frac{dx}{dt} = 2000-0,15x$$
#
# ###Preguntas planteadas
# 1. Encuentre la solución analítica de la ecuación diferencial.
#
# Iniciamos con la ecuacion principal:
#
# $$\frac{dx}{dt} = 2000-0,15x$$
#
# Procedemos a despejar $dt$:
# $$dx = dt(2000 - 0,15x)$$
#
# $$\frac{dx}{2000-0,15} = dt$$
#
# Aplicamos integracion por el metodo sustitución (vease la seccion un de metodos que vamos a usar y su aplicación):
#
# $$u = 2000 - 0,15x$$
#
# $$du = -0,15dx \Rightarrow \frac{du}{-0,15}=dx$$
#
# Procedemos a sustituir $u$ y $du$ en la ecuacion:
#
# $$\int \frac{1}{u}{du}{-0,15} = t + c$$
#
# Gracias a la propiedad de las integrales podemos sacar el -0,15 a multiplicar por la integral:
# $$\frac{1}{-0,15} \int \frac{du}{u} = t + c$$
#
# $$\frac{ln(u)}{-0,15} = t + c$$
#
# ya despues de integrar podemos volver la variable u a su estado inicial:
#
# $$\frac{ln(2000 - 0,15x)}{-0,15} = t + c$$
#
# $$ln(2000 - 0,15x) =  -0,15(t+c)$$
#
# Al -0,15 aplicamos propiedad distributiva:
#
# $$ln(2000 - 0,15x) = -0,15t -0,15 c $$
#
# Al colocar un logaritmo natural como exponente de euler podemos cancelar el logaritmo natural, esto lo vamos a implementar pero tenemos que hacerlos a ambos lados de la ecuacion para que no la afecte:
#
# $$e^{ln(2000 - 0,15x)} = e^{ -0,15t -0,15 c}$$
#
# Por medio de una de las propiedades de los exponentes podemos separar la expresion $ -0,15t -0,15 c$ en 2:
#
# $$e^{ln(2000 - 0,15x)} = e^{ -0,15t}\cdot e^{ -0,15 c}$$
#
# Podemos decir que toda la expresion $ e^{ -0,15 c}$ nos da como resultado una constante, entonces la remplazaremos por $A$ para facilidad de la ecuación:
#
# $$2000- 0,15x = e^{-0,15t}\cdot A$$
#
# Por ultimo para terminar despejamos la ecuacion para x:
#
# $$-0,15x =  e^{-0,15t}\cdot A -2000$$
#
# $$x = \frac{e^{-0,15t}\cdot A -2000}{-0,15}$$

# %% [markdown]
# 2. ¿Cuál es el valor de equilibrio de la población?
#
# Para poder hallar el equilibrio poblacional tenemos que agarrar la ecuacion inicial y igualarla a 0:
#
# $$0 = 2000-0,15x$$
#
# Continuamos despejando para x:
#
# $$-2000 = -0,15x$$
#
# $$\frac{-2000}{-0,15}=x$$
#
# $$x= 13333,33$$
#
# El equilibrio poblacional nos da en 13.333,33.

# %% [markdown]
# 3. ¿La población aumentará o disminuirá desde los
# 18000 estudiantes?
#
# Para poder determinar si la poblacion aumentara o disminuira tenemos varias formas:
#
#
# *   Por medio de la formula de la pendiente $m = \frac{y_1 - y_2}{x_1-x_2}$
# *   Por medio de la representación grafica
#
# **Por la formula de la pendiente:**
#
# Para poder usar este metodo en primera tenemos que hallar el valor de la constante $A$ que lo podemos hacer por medio de los datos iniciales que se nos dio, y al ser iniciales el tiempo seria 0:
#
# $$18000 = \frac{e^{-0,15\cdot 0}\cdot A -2000}{-0,15}$$
#
# Tenemos que despejar A en la ecuación, y tambien al saber que cualquier numero con exponente 0 da como resultado 1 podemos quitar toda la expresión $e^{-0,15\cdot 0}$
#
# $$18000 \cdot -0,15 = 1 \cdot A -2000$$
#
# $$-2700 = A -2000$$
#
# $$-2700 + 2000 = A$$
#
# $$A = -700$$
#
# Al tener el valor de A podemos empezar a aplicar la ecuacion, tenemos que usar t con cualquier valor para saber si crece o decrece, para esto usare $t=10$:
#
# $$x = \frac{e^{-0,15\cdot 10}\cdot -700 -2000}{-0,15}$$
#
# $$x = \frac{e^{-1,5}⋅ -700 -2000}{-0,15}$$
#
# $$x = \frac{0,22 \cdot -700 -2000}{-0,15}$$
#
# $$x = \frac{−156,19-2000}{-0,15}$$
#
# $$x= \frac{−2156,19}{-0,15}$$
#
# $$x = 14374.61 $$
#
# Al tener la solucion cuando el tiempo es igual a 10 años podemso hacer la formula de la pendiente con los valores iniciales y estos nuevos valores:
#
# $$m = \frac{14374,61 - 18000}{10 - 0}$$
#
# $$m = \frac{-3625,39}{10}$$
#
# $$m = -362,54$$
#
# Cuando la pendiente es negativa podemos decir que esta decrece entre esos instantes de tiempo (0años - 10años), con esto podemos decir que cada año aproximadamente disminuyeron 362,54 estudiantes en la universidad en esos 10 años.
#
#
# **Por medio de la grafica:**

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import pandas as pd

def euler(f,x0,t0,tmax,n):
    t = np.linspace(t0, tmax, n)# defina el dom up the domain based on t0, tmax, and n
    h = (tmax-t0)/n
    # next set up an array for x that is the same size a t
    x = np.zeros_like(t)
    x[0] = x0# fill in the initial condition
    for i in range( n-1 ): # think about how far we should loop
        x[i+1] = x[i]+h*f(x[i],t[i]) # advance the solution forward in time with Euler
    return x, t

r = 2000

h = 0.15

x0 = 18000

A = -700



numF = lambda x,t: r-h*x

realF = lambda t: ((np.exp(-h*t)*A)-r)/-h



numx, numt = euler(numF, x0, 0, 50, 200)



realt = np.linspace(0,50,200)

realx = realF(realt)



plt.axhline(y=13333.333, color='blue', linestyle='--', linewidth=2, label='Punto de equilibrio (13333,33)')




plt.plot(numt,numx,'g.-', label='aprox')

plt.plot(realt, realx, 'r.-', label='real')

plt.xlabel("t")

plt.ylabel("x(t)")

plt.legend()

plt.grid()

plt.show()

# %% [markdown]
# Como podemos ver en la anterior grafica en su punto inicial en los 18000 estudiantes empieza a disminuir hasta llegar a su punto de equilibrio.

# %% [markdown]
# 4. ¿Después de cuántos años se estabiliza la población al 95% del equilibrio?
#
# Para poder hacer esto tenemos que definir cuanto es el 95% del equilibrio, que equivaldria a agarrar el punto de equilibrio y sumarle 5% de si mismo:
#
# $$(13.333,33\cdot 0,05) + 13.333,33$$
#
# $$666,66 + 13.333,33$$
#
# $$13999,99$$
#
# El anterior resultado es el $95$% del punto de equilibrio, ahora tenemos que hallar en que tiempo llega a este punto, despejando e igualando en la formula:
#
#
# $$13999,99 = \frac{e^{-0,15\cdot t}\cdot -700 -2000}{-0,15}$$
#
# $$13999,99 \cdot -0,15 = e^{-0,15\cdot t}\cdot -700 -2000$$
#
# $$-2099,99 +2000 = e^{-0,15\cdot t}\cdot -700 $$
#
# $$\frac{-99,99}{-700} = e^{-0,15\cdot t}$$
#
# $$0.14 = e^{-0,15\cdot t}$$
#
# Aplicamos logaritmo natural a ambos lados para poder bajar $t$ y despejarlo para hallar en que tiempo llegamos a ese punto.
#
# $$ln(0,14) = ln(e^{-0,15\cdot t})$$
#
# $$-1,94 = -0,15 \cdot t$$
#
# $$12,97 = t$$
#
# Teniendo en cuenta esto, a los 12,97 años o aproximadamente los 13 años, se alcanza el 95% del equilibrio.
#
# 5. ¿Qué ocurre si los ingresos suben a 2500 estudiantes por año?
#
# Para poder identificar que pasa si la cantidad de estudiantes que ingresan por año aumentan a 2500
